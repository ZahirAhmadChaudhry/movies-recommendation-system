# %% [markdown]
# # Movies Recommendation System

# %% [markdown]
# Recommendation systems are machine learning techniques that help users discover relevant items or content based on their preferences, behavior, or similarity with other users. There are three main types of recommendation systems:
#
# - Content-based: This type of system recommends items or content that are similar to the ones the user has liked, rated, or interacted with in the past. The system uses the features or attributes of the items or content to measure their similarity and rank them accordingly. For example, a content-based system can recommend movies to a user based on the genres, actors, directors, or ratings of the movies they have watched before.
#
# - Collaborative filtering: This type of system recommends items or content that are popular or liked by other users who have similar tastes or preferences as the current user. The system uses the ratings, feedback, or actions of the users to learn their preferences and predict what they will like. For example, a collaborative filtering system can recommend books to a user based on the books that other users with similar reading habits have enjoyed.
#
# - Hybrid: This type of system combines the strengths of both content-based and collaborative filtering systems to overcome their limitations and provide more accurate and diverse recommendations. The system can use different methods to integrate the two approaches, such as weighted voting, feature augmentation, or model blending. For example, a hybrid system can recommend music to a user based on both the features of the songs (such as genre, artist, or mood) and the ratings or playlists of other users who have similar music tastes.

# %%
# Importing the libraries

import numpy as np
import pandas as pd 
import ast

# %%
movies = pd.read_csv('Data/tmdb_5000_movies.csv')
credits = pd.read_csv('Data/tmdb_5000_credits.csv')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies.shape
# Out:
# (4803, 20)

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
credits.shape
# Out:
# (4803, 4)

# %%
movies = movies.merge(credits,on='title')

# %%
movies.shape
# Out:
# (4809, 23)

# %% [markdown]
# # Features Selection

# %% [markdown]
# Columns we will be using
# At this point we have 23 columns, but we can see that some of them are not relevant for our model. As we are creating a content based recommendation system, we have to create tags for each movie. So, to select the columns that are useful for our model, we simply have to ask one question while looking at each column — Is this column useful for creating tags? Based on this, we have selected the following columns:
#
# i. Budget: Suppose I like a movie and its budget was high, it does not mean that I will like another movie whose budget is high. So, budget is not useful.
#
# ii. Genres: It is important. We usually get recommendations based on our favorite genres from our friends.
#
# iii. Homepage: It is not important.
#
# iv. ID: Yes, it will help us to extract posters for our website.
#
# v. Keyword: Important. These are tags.
#
# vi. Original language: We can see that 4510 data points are of English language, so this column is highly imbalanced and does not contribute much to a better recommendation model.
#
# vii. Original_title: We will keep the title column and remove the original_title, because the original title could be in the native language of the movie, but the title will be in English.
#
# viii. Overview: If the summary of two movies is similar, then the movies are also similar. So, overview is very important.
#
# ix. Popularity: As we are going to create tags for our model, and popularity is a numeric value, so it is not compatible with our approach.
#
# x. Production_Company: We usually do not recommend movies based on production companies. So, I do not think it is an important factor for a recommendation system.
#
# xi. Production_countries: As stated in point x, it also does not matter.
#
# xii. Release_date: Very important, but again a numeric value. Currently skipped. But, later I will figure out how to incorporate it in this scenario.
#
# xiii. Revenue: Does not matter.
#
# xiv. Runtime: Does not matter.
#
# xv. Spoken_languages: I think the story matters more than the spoken languages. I know some French people who watch Urdu dramas with English subtitles.
#
# xvi. Status: Released or upcoming. I think it does not matter. While sometimes it matters for the person who is searching for a good movie on Saturday night, but it does not matter for the recommendation system. Sometimes I have seen people only looking for upcoming movies. So, building a personalized recommendation system is out of the scope of this project.
#
# xvii. Tagline: Often taglines do not serve the purpose. As we already have the overview, the tagline could be skipped.
#
# xviii. Title: Yes, as discussed in original_title.
#
# xix. Vote_average: Numeric.
#
# xx. Vote_count: Numeric.
#
# xxi. Movie_id: Numeric. Also, we already have the ID.
#
# xxii. Cast: Very important. We like to watch movies of our favorite actors/actresses. Even if the movie is not good enough.
#
# xxiii. Crew: Very important. We like to watch movies from some directors. Even if the movie is not good enough.

# %%
# Selected the important features

movies = movies[['movie_id','title','overview','genres','keywords','cast','crew']]

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...

# %% [markdown]
# # Data Precossing

# %% [markdown]
# ### Handling Missing data

# %%
movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    3
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies.dropna(inplace=True)

# %%
movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    0
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...

# %% [markdown]
# ### Pre-Processing on features
#
# We have to perform followings on:
#
# - From genres column, we only need genres names e.g. Action, Adventure etc.
# - From Keywords, we only need keyword names e.g. culture clash, ocean, comics etc.
# - From cast, we only need first three main charactors real names.
# - From crew, we only need director name.
#
# We will perform pre-processing on each column individually becuase we have to extract the different information from each column.

# %% [markdown]
# #### Genres
#
# For genres, we need a function which iterate through it each dictionary and look for name, append it into list and return the list.

# %%
movies['genres'][0]
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %% [markdown]
# we can see that in genres column is a combination of dictionaries within a list, and it's represented as a string in JSON format.
# So, we need a function that converts a string representation of a list of dictionaries into a list of names. For example, if the text is `"[{'name': 'Alice', 'age': 20}, {'name': 'Bob', 'age': 25}]"`, the function will return `['Alice', 'Bob']`.
#
# To do this, we need to use the `ast.literal_eval` function from the `ast` module. This function safely evaluates a string containing a Python literal or container display, such as lists, tuples, dicts, sets, etc. It returns the corresponding Python object that the string represents.
#
# The reason why you need to use `ast.literal_eval` instead of the built-in `eval` function is that `eval` can execute any arbitrary Python code, which can be dangerous if the string comes from an untrusted source. `ast.literal_eval` only allows a limited set of Python structures, and raises an exception if the string contains anything else.

# %%
def extract_genres(inp):
    list = []
    for i in ast.literal_eval(inp):
        list.append(i['name']) 
    return list

# %%
movies['genres'] = movies['genres'].apply(extract_genres) #applying the function to the column genres
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %% [markdown]
# #### Keywords
#
# Same as above.

# %%
def extract_keywords(inp):
    list = []
    for i in ast.literal_eval(inp):
        list.append(i['name']) 
    return list

# %%
movies['keywords'] = movies['keywords'].apply(extract_keywords) #applying the function to the column keywords
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %% [markdown]
# ### Cast
#
# As diccussed erlier, we only need first three characters from each movie.

# %%
def extract_characters(inp):
    list = []
    counter = 0
    for i in ast.literal_eval(inp):
        if counter < 3:
            list.append(i['name'])
        counter+=1
    return list

# %%
movies['cast'] = movies['cast'].apply(extract_characters) #applying the function to the column cast
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies['cast'] = movies['cast'].apply(lambda x:x[0:3])

# %% [markdown]
# #### Crew
#
# From crew, we only interested in the director name.

# %%
def extract_director(inp):
    list = []
    for i in ast.literal_eval(inp):
        if i['job'] == 'Director':
            list.append(i['name'])
    return list

# %%
movies['crew'] = movies['crew'].apply(extract_director) #applying the function to the column crew
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %% [markdown]
# We are done with desired information extration from desired columns. Now, we can see that in genres, keywords, cast, and crew we have words with spaces. When we will convert them into tags, each words will be treated as single tag e.g. for Sam Mendes tags will be #Sam #Mendes. That is a problem. So, we need to remove the spaces between words of these columns. Here how we will do that.

# %%
def no_spaces(inp):
    list_1 = []
    for i in inp:
        list_1.append(i.replace(" ",""))
    return list_1

# %%
movies['cast'] = movies['cast'].apply(no_spaces)
movies['crew'] = movies['crew'].apply(no_spaces)
movies['genres'] = movies['genres'].apply(no_spaces)
movies['keywords'] = movies['keywords'].apply(no_spaces)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
# ...

# %% [markdown]
# #### Overview
# For overview column, we need to split the paragraphs/sentences into words. As follows.

# %%
movies['overview'] = movies['overview'].apply(lambda x:x.split())

# %% [markdown]
# Concatinating desired columns into tags column and then removing them from the movies dataset to acheive the desired dataset for vertorization.

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']

# %%
desired_df = movies.drop(columns=['overview','genres','keywords','cast','crew'])
desired_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...

# %% [markdown]
# Now, we are going to convert the tags column words into single paragraphs.

# %%
desired_df['tags'] = desired_df['tags'].apply(lambda x: " ".join(x))
desired_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %%
desired_df['tags'][0]
# Out:
# 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization. Action Adventure Fantasy ScienceFiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d SamWorthington ZoeSaldana SigourneyWeaver JamesCameron'

# %%
# to lower case
desired_df['tags'] = desired_df['tags'].apply(lambda x:x.lower())

# %%
desired_df
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4804      9367                               El Mariachi
# 4805     72766                                 Newlyweds
# 4806    231617                 Signed, Sealed, Delivered
# 4807    126186                          Shanghai Calling
# 4808     25975                         My Date with Drew
#
#                                                    tags
# 0     in the 22nd century, a paraplegic marine is di...
# 1     captain barbossa, long believed to be dead, ha...
# 2     a cryptic message from bond’s past sends him o...
# ...

# %% [markdown]
# # Vectorization

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk import pos_tag, word_tokenize

# %%
import string
from nltk.corpus import stopwords

# Lemmatization is the process of converting a word to its base form

def get_wordnet_pos(pos_tag):
    if pos_tag.startswith('J'):
        return wordnet.ADJ
    elif pos_tag.startswith('V'):
        return wordnet.VERB
    elif pos_tag.startswith('N'):
        return wordnet.NOUN
    elif pos_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN
    
def clean_text(text):
    # lower text
    text = text.lower()
    # tokenize text and remove puncutation
    text = [word.strip(string.punctuation) for word in text.split(" ")]
    # remove words that contain numbers
    #text = [word for word in text if not any(c.isdigit() for c in word)]
    # remove stop words
    stop = stopwords.words('english')
    text = [x for x in text if x not in stop]
    # remove empty tokens
    text = [t for t in text if len(t) > 0]
    # pos tag text
    pos_tags = pos_tag(text)
    # lemmatize text
    text = [WordNetLemmatizer().lemmatize(t[0], get_wordnet_pos(t[1])) for t in pos_tags]
    # remove words with only one letter
    text = [t for t in text if len(t) > 1]
    # join all
    text = " ".join(text)
    return(text)

# apply function on the tags
desired_df['tags'] = desired_df['tags'].apply(lambda x: clean_text(x))

desired_df['tags'][0]
# Out:
# '22nd century paraplegic marine dispatch moon pandora unique mission become torn follow order protect alien civilization action adventure fantasy sciencefiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d samworthington zoesaldana sigourneyweaver jamescameron'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(max_features=5000, stop_words='english')
vector = tfidf.fit_transform(movies['tags'].apply(lambda x: " ".join(x)))

# %% [markdown]
# When calculating the distance between movies based on their tags (which are represented as vectors), using **Euclidean distance** is not ideal because it measures the straight-line distance between two points (tip to tip). This method is sensitive to the magnitude of the vectors, meaning that movies with different numbers of tags or varying tag importance could end up being far apart, even if they share similar themes or concepts. Euclidean distance doesn't capture the similarity in direction between the vectors, so two movies that are semantically similar but have varying levels of tag importance could be considered distant.
#
# Instead, we use **cosine distance** (or cosine similarity) because it measures the angle between the two vectors, not the magnitude. This technique focuses on the direction of the vectors, making it more suitable for comparing text-based data like movie tags. Cosine distance values range from 0 to 1, where 0 means the vectors are identical in direction (high similarity) and 1 means they are orthogonal (completely different). By using cosine distance, we can compare how closely aligned the tags are between movies, regardless of how many tags each movie has or their magnitudes, leading to more meaningful comparisons in recommendation systems.

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity_matrix = cosine_similarity(vector)

# %%
similarity_matrix.shape
# Out:
# (4806, 4806)

# %%
similarity_matrix[0]
# Out:
# array([1.        , 0.02304335, 0.01284023, ..., 0.00565329, 0.00625386,
#        0.        ])

# %%
def recommend(movie, num_recommendations=5):
    if movie not in movies['title'].values:
        print("Movie not found in the dataset")
        return
    
    # Get the index of the movie
    index = movies[movies['title'] == movie].index[0]
    distances = similarity_matrix[index]
    
    # Get movie indices and sort them based on similarity score
    movies_index_list = sorted(list(enumerate(distances)), reverse=True, key=lambda x: x[1])[1:num_recommendations+1]
    
    # Display recommended movies along with their similarity score
    for i in movies_index_list:
        recommended_movie = movies.iloc[i[0]].title
        similarity_score = i[1]
        print(f"Movie: {recommended_movie}, Similarity Score: {similarity_score:.2f}")

# %%
recommend('Ratatouille')
# Out:
# Movie: No Reservations, Similarity Score: 0.27
# Movie: Burnt, Similarity Score: 0.24
# Movie: Simply Irresistible, Similarity Score: 0.23
# Movie: Flushed Away, Similarity Score: 0.19
# Movie: The Hundred-Foot Journey, Similarity Score: 0.19

# %% [markdown]
# # Testing

# %%
# Function to calculate Precision at K
def precision_at_k(recommended_movies, actual_movies, k=5):
    relevant = 0
    for movie in recommended_movies[:k]:
        if movie in actual_movies:
            relevant += 1
    precision = relevant / k
    return precision

# Function to get recommendations and return as a list
def get_recommendations(movie, num_recommendations=5):
    if movie not in movies['title'].values:
        print("Movie not found in the dataset")
        return []
    
    index = movies[movies['title'] == movie].index[0]
    distances = similarity_matrix[index]
    
    # Get movie indices and sort them based on similarity score
    movies_index_list = sorted(list(enumerate(distances)), reverse=True, key=lambda x: x[1])[1:num_recommendations+1]
    
    # Return list of recommended movie titles
    recommended_movies = [movies.iloc[i[0]].title for i in movies_index_list]
    return recommended_movies

# test case: Actual relevant movies (ground truth) for 'Ratatouille'
actual_relevant_movies = ['The Master of Disguise', 'Simply Irresistible', 'Flushed Away']

# Get recommended movies for 'Ratatouille'
recommended_movies = get_recommendations('Ratatouille', num_recommendations=6)

# Calculate Precision at K
precision = precision_at_k(recommended_movies, actual_relevant_movies, k=5)
print(f'Precision at K: {precision}')
# Out:
# Precision at K: 0.4
